# %% [markdown]
# # Data Validation
# This notebook validates raw inputs and processed outputs.

# %%
import pandas as pd
from src.utils import RAW_DIR, PROCESSED_DIR
teams = pd.read_csv(RAW_DIR / 'teams_master.csv')
teams.head()
