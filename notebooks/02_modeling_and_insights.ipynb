# %% [markdown]
# # Modeling and Insights
# Explores CPI drivers, demand model, and revenue scenarios.

# %%
import pandas as pd
from src.utils import PROCESSED_DIR
df = pd.read_csv(PROCESSED_DIR / 'club_metrics.csv')
df.head()
